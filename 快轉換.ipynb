# %% [markdown]
# <a href="https://colab.research.google.com/github/SAGISHIRA/SAGISHIRA/blob/main/%E5%BF%AB%E8%BD%89%E6%8F%9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Youtube Videos Transcription with Faster Whisper**
#
#
# [![notebook shield](https://img.shields.io/static/v1?label=&message=Notebook&color=blue&style=for-the-badge&logo=googlecolab&link=https://colab.research.google.com/github/ArthurFDLR/whisper-youtube/blob/main/whisper_youtube.ipynb)](https://colab.research.google.com/github/lewangdev/whisper-youtube/blob/main/faster_whisper_youtube.ipynb)
# [![repository shield](https://img.shields.io/static/v1?label=&message=Repository&color=blue&style=for-the-badge&logo=github&link=https://github.com/lewangdev/faster_whisper_youtube)](https://github.com/lewangdev/faster_whisper_youtube)
#
#
# [faster-whisper](https://github.com/guillaumekln/faster-whisper) is a reimplementation of OpenAI's Whisper model using CTranslate2, which is a fast inference engine for Transformer models.
#
# This implementation is up to 4 times faster than openai/whisper for the same accuracy while using less memory. The efficiency can be further improved with 8-bit quantization on both CPU and GPU.
#
# Whisper is a general-purpose speech recognition model. It is trained on a large dataset of diverse audio and is also a multi-task model that can perform multilingual speech recognition as well as speech translation and language identification.
#
# This Notebook will guide you through the transcription of a Youtube video using Faster Whisper. You'll be able to explore most inference parameters or use the Notebook as-is to store the transcript and video audio in your Google Drive.

# %%
#@markdown # **Check GPU type** 🕵️

#@markdown The type of GPU you get assigned in your Colab session defined the speed at which the video will be transcribed.
#@markdown The higher the number of floating point operations per second (FLOPS), the faster the transcription.
#@markdown But even the least powerful GPU available in Colab is able to run any Whisper model.
#@markdown Make sure you've selected `GPU` as hardware accelerator for the Notebook (Runtime &rarr; Change runtime type &rarr; Hardware accelerator).

#@markdown |  GPU   |  GPU RAM   | FP32 teraFLOPS |     Availability   |
#@markdown |:------:|:----------:|:--------------:|:------------------:|
#@markdown |  T4    |    16 GB   |       8.1      |         Free       |
#@markdown | P100   |    16 GB   |      10.6      |      Colab Pro     |
#@markdown | V100   |    16 GB   |      15.7      |  Colab Pro (Rare)  |

#@markdown ---
#@markdown **Factory reset your Notebook's runtime if you want to get assigned a new GPU.**

# !nvidia-smi -L

# !nvidia-smi
# Out:
# GPU 0: Tesla T4 (UUID: GPU-c899e978-087d-c647-feaf-a0835081a4c6)
# Tue Aug 15 03:32:10 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0    31W /  70W |   1133MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
#@markdown # **Install libraries** 🏗️
#@markdown This cell will take a little while to download several libraries, including Faster Whisper.

#@markdown ---

! pip install faster-whisper
! pip install yt-dlp

import sys
import warnings
from faster_whisper import WhisperModel
from pathlib import Path
import yt_dlp
import subprocess
import torch
import shutil
import numpy as np
from IPython.display import display, Markdown, YouTubeVideo

device = torch.device('cuda:0')
print('Using device:', device, file=sys.stderr)
# Out:
# Requirement already satisfied: faster-whisper in /usr/local/lib/python3.10/dist-packages (0.7.1)
# Requirement already satisfied: av==10.* in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (10.0.0)
# Requirement already satisfied: ctranslate2<4,>=3.17 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.13 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (0.16.4)
# Requirement already satisfied: tokenizers==0.13.* in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (0.13.3)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /usr/local/lib/python3.10/dist-packages (from faster-whisper) (1.15.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.17->faster-whisper) (1.23.5)
# Requirement already satisfied: pyyaml<7,>=5.3 in /usr/local/lib/python3.10/dist-packages (from ctranslate2<4,>=3.17->faster-whisper) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.66.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13->faster-whisper) (23.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (23.5.26)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime<2,>=1.14->faster-whisper) (1.12)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime<2,>=1.14->faster-whisper) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.13->faster-whisper) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime<2,>=1.14->faster-whisper) (1.3.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2023.7.6)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.46.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (3.18.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (11.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2023.7.22)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.0.9)
# Using device: cuda:0

# %%
#@markdown # **Optional:** Save data in Google Drive 💾
#@markdown Enter a Google Drive path and run this cell if you want to store the results inside Google Drive.

# Uncomment to copy generated images to drive, faster than downloading directly from colab in my experience.
from google.colab import drive
drive_mount_path = Path("/") / "content" / "drive"
drive.mount(str(drive_mount_path))
drive_mount_path /= "My Drive"
#@markdown ---
drive_path = "Colab Notebooks/Faster Whisper Youtube" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change your Google Drive path.**

drive_whisper_path = drive_mount_path / Path(drive_path.lstrip("/"))
drive_whisper_path.mkdir(parents=True, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@markdown # **Model selection** 🧠

#@markdown As of the first public release, there are 4 pre-trained options to play with:

#@markdown |  Size  | Parameters | English-only model | Multilingual model | Required VRAM | Relative speed |
#@markdown |:------:|:----------:|:------------------:|:------------------:|:-------------:|:--------------:|
#@markdown |  tiny  |    39 M    |     `tiny.en`      |       `tiny`       |     ~0.8 GB     |      ~32x      |
#@markdown |  base  |    74 M    |     `base.en`      |       `base`       |     ~1.0 GB     |      ~16x      |
#@markdown | small  |   244 M    |     `small.en`     |      `small`       |     ~1.4 GB     |      ~6x       |
#@markdown | medium |   769 M    |    `medium.en`     |      `medium`      |     ~2.7 GB     |      ~2x       |
#@markdown | large-v1  |   1550 M   |        N/A         |      `large-v1`       |    ~4.3 GB     |       1x       |
#@markdown | large-v2  |   1550 M   |        N/A         |      `large-v2`       |    ~4.3 GB     |       1x       |

#@markdown ---
model_size = 'medium' #@param ['tiny', 'tiny.en', 'base', 'base.en', 'small', 'small.en', 'medium', 'medium.en', 'large-v1', 'large-v2']
device_type = "cuda" #@param {type:"string"} ['cuda', 'cpu']
compute_type = "int8" #@param {type:"string"} ['float16', 'int8_float16', 'int8']
#@markdown ---
#@markdown **Run this cell again if you change the model.**

model = WhisperModel(model_size, device=device_type, compute_type=compute_type)

# %%
#@markdown # **Video selection** 📺

#@markdown Enter the URL of the Youtube video you want to transcribe, wether you want to save the audio file in your Google Drive, and run the cell.

Type = "Youtube video or playlist" #@param ['Youtube video or playlist', 'Google Drive']
#@markdown ---
#@markdown #### **Youtube video or playlist**
URL = "https://www.youtube.com/watch?v=PJJhHihvDpo&list=RD_ID2livKrUk&index=11" #@param {type:"string"}
# store_audio = True #@param {type:"boolean"}
#@markdown ---
#@markdown #### **Google Drive video, audio (mp4, wav), or folder containing video and/or audio files**
video_path = "Colab Notebooks/transcription/my_video.mp4" #@param {type:"string"}
#@markdown ---
#@markdown **Run this cell again if you change the video.**

video_path_local_list = []

if Type == "Youtube video or playlist":

    ydl_opts = {
        'format': 'm4a/bestaudio/best',
        'outtmpl': '%(id)s.%(ext)s',
        # ℹ️ See help(yt_dlp.postprocessor) for a list of available Postprocessors and their arguments
        'postprocessors': [{  # Extract audio using ffmpeg
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'wav',
        }]
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        error_code = ydl.download([URL])
        list_video_info = [ydl.extract_info(URL, download=False)]

    for video_info in list_video_info:
        video_path_local_list.append(Path(f"{video_info['id']}.wav"))

elif Type == "Google Drive":
    # video_path_drive = drive_mount_path / Path(video_path.lstrip("/"))
    video_path = drive_mount_path / Path(video_path.lstrip("/"))
    if video_path.is_dir():
        for video_path_drive in video_path.glob("**/*"):
            if video_path_drive.is_file():
                display(Markdown(f"**{str(video_path_drive)} selected for transcription.**"))
            elif video_path_drive.is_dir():
                display(Markdown(f"**Subfolders not supported.**"))
            else:
                display(Markdown(f"**{str(video_path_drive)} does not exist, skipping.**"))
            video_path_local = Path(".").resolve() / (video_path_drive.name)
            shutil.copy(video_path_drive, video_path_local)
            video_path_local_list.append(video_path_local)
    elif video_path.is_file():
        video_path_local = Path(".").resolve() / (video_path.name)
        shutil.copy(video_path, video_path_local)
        video_path_local_list.append(video_path_local)
        display(Markdown(f"**{str(video_path)} selected for transcription.**"))
    else:
        display(Markdown(f"**{str(video_path)} does not exist.**"))

else:
    raise(TypeError("Please select supported input type."))

for video_path_local in video_path_local_list:
    if video_path_local.suffix == ".mp4":
        video_path_local = video_path_local.with_suffix(".wav")
        result  = subprocess.run(["ffmpeg", "-i", str(video_path_local.with_suffix(".mp4")), "-vn", "-acodec", "pcm_s16le", "-ar", "16000", "-ac", "1", str(video_path_local)])
# Out:
# Streaming output truncated to the last 5000 lines.
# [ExtractAudio] Destination: 0UFVQ6SoIVI.wav
# Deleting original file 0UFVQ6SoIVI.m4a (pass -k to keep)
# [download] Downloading item 364 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=P7Qv4AV_StM
# [youtube] P7Qv4AV_StM: Downloading webpage
# [youtube] P7Qv4AV_StM: Downloading ios player API JSON
# [youtube] P7Qv4AV_StM: Downloading android player API JSON
# [youtube] P7Qv4AV_StM: Downloading m3u8 information
# [info] P7Qv4AV_StM: Downloading 1 format(s): 140
# [download] Destination: P7Qv4AV_StM.m4a
# [download] 100% of    3.95MiB in 00:00:00 at 55.46MiB/s
# [FixupM4a] Correcting container of "P7Qv4AV_StM.m4a"
# [ExtractAudio] Destination: P7Qv4AV_StM.wav
# Deleting original file P7Qv4AV_StM.m4a (pass -k to keep)
# [download] Downloading item 365 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TycGHSKQBvc
# [youtube] TycGHSKQBvc: Downloading webpage
# [youtube] TycGHSKQBvc: Downloading ios player API JSON
# [youtube] TycGHSKQBvc: Downloading android player API JSON
# [youtube] TycGHSKQBvc: Downloading m3u8 information
# [info] TycGHSKQBvc: Downloading 1 format(s): 140
# [download] Destination: TycGHSKQBvc.m4a
# [download] 100% of    4.35MiB in 00:00:00 at 37.05MiB/s
# [FixupM4a] Correcting container of "TycGHSKQBvc.m4a"
# [ExtractAudio] Destination: TycGHSKQBvc.wav
# Deleting original file TycGHSKQBvc.m4a (pass -k to keep)
# [download] Downloading item 366 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MkptBXsgNcw
# [youtube] MkptBXsgNcw: Downloading webpage
# [youtube] MkptBXsgNcw: Downloading ios player API JSON
# [youtube] MkptBXsgNcw: Downloading android player API JSON
# [youtube] MkptBXsgNcw: Downloading m3u8 information
# [info] MkptBXsgNcw: Downloading 1 format(s): 140
# [download] Destination: MkptBXsgNcw.m4a
# [download] 100% of    3.84MiB in 00:00:00 at 17.77MiB/s
# [FixupM4a] Correcting container of "MkptBXsgNcw.m4a"
# [ExtractAudio] Destination: MkptBXsgNcw.wav
# Deleting original file MkptBXsgNcw.m4a (pass -k to keep)
# [download] Downloading item 367 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VqRfXIalMnY
# [youtube] VqRfXIalMnY: Downloading webpage
# [youtube] VqRfXIalMnY: Downloading ios player API JSON
# [youtube] VqRfXIalMnY: Downloading android player API JSON
# [youtube] VqRfXIalMnY: Downloading m3u8 information
# [info] VqRfXIalMnY: Downloading 1 format(s): 140
# [download] Destination: VqRfXIalMnY.m4a
# [download] 100% of    3.39MiB in 00:00:00 at 28.65MiB/s
# [FixupM4a] Correcting container of "VqRfXIalMnY.m4a"
# [ExtractAudio] Destination: VqRfXIalMnY.wav
# Deleting original file VqRfXIalMnY.m4a (pass -k to keep)
# [download] Downloading item 368 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ar3bOrpPHk0
# [youtube] Ar3bOrpPHk0: Downloading webpage
# [youtube] Ar3bOrpPHk0: Downloading ios player API JSON
# [youtube] Ar3bOrpPHk0: Downloading android player API JSON
# [youtube] Ar3bOrpPHk0: Downloading m3u8 information
# [info] Ar3bOrpPHk0: Downloading 1 format(s): 140
# [download] Destination: Ar3bOrpPHk0.m4a
# [download] 100% of    2.93MiB in 00:00:00 at 36.13MiB/s
# [FixupM4a] Correcting container of "Ar3bOrpPHk0.m4a"
# [ExtractAudio] Destination: Ar3bOrpPHk0.wav
# Deleting original file Ar3bOrpPHk0.m4a (pass -k to keep)
# [download] Downloading item 369 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YT6keCFwu2w
# [youtube] YT6keCFwu2w: Downloading webpage
# [youtube] YT6keCFwu2w: Downloading ios player API JSON
# [youtube] YT6keCFwu2w: Downloading android player API JSON
# [youtube] YT6keCFwu2w: Downloading m3u8 information
# [info] YT6keCFwu2w: Downloading 1 format(s): 140
# [download] Destination: YT6keCFwu2w.m4a
# [download] 100% of    3.73MiB in 00:00:00 at 31.38MiB/s
# [FixupM4a] Correcting container of "YT6keCFwu2w.m4a"
# [ExtractAudio] Destination: YT6keCFwu2w.wav
# Deleting original file YT6keCFwu2w.m4a (pass -k to keep)
# [download] Downloading item 370 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v
of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=baV20uuhqMk
# [youtube] baV20uuhqMk: Downloading webpage
# [youtube] baV20uuhqMk: Downloading ios player API JSON
# [youtube] baV20uuhqMk: Downloading android player API JSON
# [youtube] baV20uuhqMk: Downloading m3u8 information
# [info] baV20uuhqMk: Downloading 1 format(s): 140
# [download] Destination: baV20uuhqMk.m4a
# [download] 100% of    3.06MiB in 00:00:00 at 25.15MiB/s
# [FixupM4a] Correcting container of "baV20uuhqMk.m4a"
# [ExtractAudio] Destination: baV20uuhqMk.wav
# Deleting original file baV20uuhqMk.m4a (pass -k to keep)
# [download] Downloading item 380 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jSQsiv6PpLA
# [youtube] jSQsiv6PpLA: Downloading webpage
# [youtube] jSQsiv6PpLA: Downloading ios player API JSON
# [youtube] jSQsiv6PpLA: Downloading android player API JSON
# [youtube] jSQsiv6PpLA: Downloading m3u8 information
# [info] jSQsiv6PpLA: Downloading 1 format(s): 140
# [download] Destination: jSQsiv6PpLA.m4a
# [download] 100% of    4.16MiB in 00:00:00 at 17.33MiB/s
# [FixupM4a] Correcting container of "jSQsiv6PpLA.m4a"
# [ExtractAudio] Destination: jSQsiv6PpLA.wav
# Deleting original file jSQsiv6PpLA.m4a (pass -k to keep)
# [download] Downloading item 381 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OfnKKg4G1rc
# [youtube] OfnKKg4G1rc: Downloading webpage
# [youtube] OfnKKg4G1rc: Downloading ios player API JSON
# [youtube] OfnKKg4G1rc: Downloading android player API JSON
# [youtube] OfnKKg4G1rc: Downloading m3u8 information
# [info] OfnKKg4G1rc: Downloading 1 format(s): 140
# [download] Destination: OfnKKg4G1rc.m4a
# [download] 100% of    3.59MiB in 00:00:00 at 27.60MiB/s
# [FixupM4a] Correcting container of "OfnKKg4G1rc.m4a"
# [ExtractAudio] Destination: OfnKKg4G1rc.wav
# Deleting original file OfnKKg4G1rc.m4a (pass -k to keep)
# [download] Downloading item 382 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ns1m5FRhbn4
# [youtube] ns1m5FRhbn4: Downloading webpage
# [youtube] ns1m5FRhbn4: Downloading ios player API JSON
# [youtube] ns1m5FRhbn4: Downloading android player API JSON
# [youtube] ns1m5FRhbn4: Downloading m3u8 information
# [info] ns1m5FRhbn4: Downloading 1 format(s): 140
# [download] Destination: ns1m5FRhbn4.m4a
# [download] 100% of    5.17MiB in 00:00:00 at 35.52MiB/s
# [FixupM4a] Correcting container of "ns1m5FRhbn4.m4a"
# [ExtractAudio] Destination: ns1m5FRhbn4.wav
# Deleting original file ns1m5FRhbn4.m4a (pass -k to keep)
# [download] Downloading item 383 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AGUoh8-OeZk
# [youtube] AGUoh8-OeZk: Downloading webpage
# [youtube] AGUoh8-OeZk: Downloading ios player API JSON
# [youtube] AGUoh8-OeZk: Downloading android player API JSON
# [youtube] AGUoh8-OeZk: Downloading m3u8 information
# [info] AGUoh8-OeZk: Downloading 1 format(s): 140
# [download] Destination: AGUoh8-OeZk.m4a
# [download] 100% of    4.78MiB in 00:00:00 at 9.90MiB/s
# [FixupM4a] Correcting container of "AGUoh8-OeZk.m4a"
# [ExtractAudio] Destination: AGUoh8-OeZk.wav
# Deleting original file AGUoh8-OeZk.m4a (pass -k to keep)
# [download] Downloading item 384 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=
of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=F8lCfxJ1MTQ
# [youtube] F8lCfxJ1MTQ: Downloading webpage
# [youtube] F8lCfxJ1MTQ: Downloading ios player API JSON
# [youtube] F8lCfxJ1MTQ: Downloading android player API JSON
# [youtube] F8lCfxJ1MTQ: Downloading m3u8 information
# [info] F8lCfxJ1MTQ: Downloading 1 format(s): 140
# [download] Destination: F8lCfxJ1MTQ.m4a
# [download] 100% of    4.15MiB in 00:00:00 at 28.98MiB/s
# [FixupM4a] Correcting container of "F8lCfxJ1MTQ.m4a"
# [ExtractAudio] Destination: F8lCfxJ1MTQ.wav
# Deleting original file F8lCfxJ1MTQ.m4a (pass -k to keep)
# [download] Downloading item 390 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mwZSQBixpFE
# [youtube] mwZSQBixpFE: Downloading webpage
# [youtube] mwZSQBixpFE: Downloading ios player API JSON
# [youtube] mwZSQBixpFE: Downloading android player API JSON
# [youtube] mwZSQBixpFE: Downloading m3u8 information
# [info] mwZSQBixpFE: Downloading 1 format(s): 140
# [download] Destination: mwZSQBixpFE.m4a
# [download] 100% of    5.07MiB in 00:00:00 at 35.01MiB/s
# [FixupM4a] Correcting container of "mwZSQBixpFE.m4a"
# [ExtractAudio] Destination: mwZSQBixpFE.wav
# Deleting original file mwZSQBixpFE.m4a (pass -k to keep)
# [download] Downloading item 391 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AM9W--YXERk
# [youtube] AM9W--YXERk: Downloading webpage
# [youtube] AM9W--YXERk: Downloading ios player API JSON
# [youtube] AM9W--YXERk: Downloading android player API JSON
# [youtube] AM9W--YXERk: Downloading m3u8 information
# [info] AM9W--YXERk: Downloading 1 format(s): 140
# [download] Destination: AM9W--YXERk.m4a
# [download] 100% of    4.02MiB in 00:00:00 at 34.68MiB/s
# [FixupM4a] Correcting container of "AM9W--YXERk.m4a"
# [ExtractAudio] Destination: AM9W--YXERk.wav
# Deleting original file AM9W--YXERk.m4a (pass -k to keep)
# [download] Downloading item 392 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0F18CyCwT3w
# [youtube] 0F18CyCwT3w: Downloading webpage
# [youtube] 0F18CyCwT3w: Downloading ios player API JSON
# [youtube] 0F18CyCwT3w: Downloading android player API JSON
# [youtube] 0F18CyCwT3w: Downloading m3u8 information
# [info] 0F18CyCwT3w: Downloading 1 format(s): 140
# [download] Destination: 0F18CyCwT3w.m4a
# [download] 100% of    3.16MiB in 00:00:00 at 29.43MiB/s
# [FixupM4a] Correcting container of "0F18CyCwT3w.m4a"
# [ExtractAudio] Destination: 0F18CyCwT3w.wav
# Deleting original file 0F18CyCwT3w.m4a (pass -k to keep)
# [download] Downloading item 393 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vh-lDIc-biU
# [youtube] vh-lDIc-biU: Downloading webpage
# [youtube] vh-lDIc-biU: Downloading ios player API JSON
# [youtube] vh-lDIc-biU: Downloading android player API JSON
# [youtube] vh-lDIc-biU: Downloading m3u8 information
# [info] vh-lDIc-biU: Downloading 1 format(s): 140
# [download] Destination: vh-lDIc-biU.m4a
# [download] 100% of    5.91MiB in 00:00:00 at 40.65MiB/s
# [FixupM4a] Correcting container of "vh-lDIc-biU.m4a"
# [ExtractAudio] Destination: vh-lDIc-biU.wav
# Deleting original file vh-lDIc-biU.m4a (pass -k to keep)
# [download] Downloading item 394 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dSLQwzx1CWg
# [youtube] dSLQwzx1CWg: Downloading webpage
# [youtube] dSLQwzx1CWg: Downloading ios player API JSON
# [youtube] dSLQwzx1CWg: Downloading android player API JSON
# [youtube] dSLQwzx1CWg: Downloading m3u8 information
# [info] dSLQwzx1CWg: Downloading 1 format(s): 140
# [download] Destination: dSLQwzx1CWg.m4a
# [download] 100% of    3.75MiB in 00:00:00 at 39.49MiB/s
# [FixupM4a] Correcting container of "dSLQwzx1CWg.m4a"
# [ExtractAudio] Destination: dSLQwzx1CWg.wav
# Deleting original file dSLQwzx1CWg.m4a (pass -k to keep)
# [download] Downloading item 395 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3FbaXAEjLhk
# [youtube] 3FbaXAEjLhk: Downloading webpage
# [youtube] 3FbaXAEjLhk: Downloading ios player API JSON
# [youtube] 3FbaXAEjLhk: Downloading android player API JSON
# [youtube] 3FbaXAEjLhk: Downloading m3u8 information
# [info] 3FbaXAEjLhk: Downloading 1 format(s): 140
# [download] Destination: 3FbaXAEjLhk.m4a
# [download] 100% of    4.21MiB in 00:00:00 at 26.79MiB/s
# [FixupM4a] Correcting container of "3FbaXAEjLhk.m4a"
# [ExtractAudio] Destination: 3FbaXAEjLhk.wav
# Deleting original file 3FbaXAEjLhk.m4a (pass -k to keep)
# [download] Downloading item 396 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=spDre5vKUHk
# [youtube] spDre5vKUHk: Downloading webpage
# [youtube] spDre5vKUHk: Downloading ios player API JSON
# [youtube] spDre5vKUHk: Downloading android player API JSON
# [youtube] spDre5vKUHk: Downloading m3u8 information
# [info] spDre5vKUHk: Downloading 1 format(s): 140
# [download] Destination: spDre5vKUHk.m4a
# [download] 100% of    4.80MiB in 00:00:00 at 9.34MiB/s
# [FixupM4a] Correcting container of "spDre5vKUHk.m4a"
# [ExtractAudio] Destination: spDre5vKUHk.wav
# Deleting original file spDre5vKUHk.m4a (pass -k to keep)
# [download] Downloading item 397 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=N_-BGZyNUBs
# [youtube] N_-BGZyNUBs: Downloading webpage
# [youtube] N_-BGZyNUBs: Downloading ios player API JSON
# [youtube] N_-BGZyNUBs: Downloading android player API JSON
# [youtube] N_-BGZyNUBs: Downloading m3u8 information
# [info] N_-BGZyNUBs: Downloading 1 format(s): 140
# [download] Destination: N_-BGZyNUBs.m4a
# [download] 100% of    4.11MiB in 00:00:00 at 26.86MiB/s
# [FixupM4a] Correcting container of "N_-BGZyNUBs.m4a"
# [ExtractAudio] Destination: N_-BGZyNUBs.wav
# Deleting original file N_-BGZyNUBs.m4a (pass -k to keep)
# [download] Downloading item 398 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hE8kr4UuTTQ
# [youtube] hE8kr4UuTTQ: Downloading webpage
# [youtube] hE8kr4UuTTQ: Downloading ios player API JSON
# [youtube] hE8kr4UuTTQ: Downloading android player API JSON
# [youtube] hE8kr4UuTTQ: Downloading m3u8 information
# [info] hE8kr4UuTTQ: Downloading 1 format(s): 140
# [download] Destination: hE8kr4UuTTQ.m4a
# [download] 100% of    4.24MiB in 00:00:00 at 35.12MiB/s
# [FixupM4a] Correcting container of "hE8kr4UuTTQ.m4a"
# [ExtractAudio] Destination: hE8kr4UuTTQ.wav
# Deleting original file hE8kr4UuTTQ.m4a (pass -k to keep)
# [download] Downloading item 399 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4Emk0mK2dvE
# [youtube] 4Emk0mK2dvE: Downloading webpage
# [youtube] 4Emk0mK2dvE: Downloading ios player API JSON
# [youtube] 4Emk0mK2dvE: Downloading android player API JSON
# [youtube] 4Emk0mK2dvE: Downloading m3u8 information
# [info] 4Emk0mK2dvE: Downloading 1 format(s): 140
# [download] Destination: 4Emk0mK2dvE.m4a
# [download] 100% of    3.68MiB in 00:00:00 at 32.12MiB/s
# [FixupM4a] Correcting container of "4Emk0mK2dvE.m4a"
# [ExtractAudio] Destination: 4Emk0mK2dvE.wav
# Deleting original file 4Emk0mK2dvE.m4a (pass -k to keep)
# [download] Downloading item 400 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SEjiyJ04uig
# [youtube] SEjiyJ04uig: Downloading webpage
# [youtube] SEjiyJ04uig: Downloading ios player API JSON
# [youtube] SEjiyJ04uig: Downloading android player API JSON
# [youtube] SEjiyJ04uig: Downloading m3u8 information
# [info] SEjiyJ04uig: Downloading 1 format(s): 140
# [download] Destination: SEjiyJ04uig.m4a
# [download] 100% of    4.50MiB in 00:00:00 at 24.01MiB/s
# [FixupM4a] Correcting container of "SEjiyJ04uig.m4a"
# [ExtractAudio] Destination: SEjiyJ04uig.wav
# Deleting original file SEjiyJ04uig.m4a (pass -k to keep)
# [download] Downloading item 401 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I3FHA_qASro
# [youtube] I3FHA_qASro: Downloading webpage
# [youtube] I3FHA_qASro: Downloading ios player API JSON
# [youtube] I3FHA_qASro: Downloading android player API JSON
# [youtube] I3FHA_qASro: Downloading m3u8 information
# [info] I3FHA_qASro: Downloading 1 format(s): 140
# [download] Destination: I3FHA_qASro.m4a
# [download] 100% of    4.69MiB in 00:00:00 at 32.98MiB/s
# [FixupM4a] Correcting container of "I3FHA_qASro.m4a"
# [ExtractAudio] Destination: I3FHA_qASro.wav
# Deleting original file I3FHA_qASro.m4a (pass -k to keep)
# [download] Downloading item 402 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NJX50y15rvw
# [youtube] NJX50y15rvw: Downloading webpage
# [youtube] NJX50y15rvw: Downloading ios player API JSON
# [youtube] NJX50y15rvw: Downloading android player API JSON
# [youtube] NJX50y15rvw: Downloading m3u8 information
# [info] NJX50y15rvw: Downloading 1 format(s): 140
# [download] Destination: NJX50y15rvw.m4a
# [download] 100% of    4.44MiB in 00:00:00 at 22.20MiB/s
# [FixupM4a] Correcting container of "NJX50y15rvw.m4a"
# [ExtractAudio] Destination: NJX50y15rvw.wav
# Deleting original file NJX50y15rvw.m4a (pass -k to keep)
# [download] Downloading item 403 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0VHX2ovsx6E
# [youtube] 0VHX2ovsx6E: Downloading webpage
# [youtube] 0VHX2ovsx6E: Downloading ios player API JSON
# [youtube] 0VHX2ovsx6E: Downloading android player API JSON
# [youtube] 0VHX2ovsx6E: Downloading m3u8 information
# [info] 0VHX2ovsx6E: Downloading 1 format(s): 140
# [download] Destination: 0VHX2ovsx6E.m4a
# [download] 100% of    3.27MiB in 00:00:00 at 39.60MiB/s
# [FixupM4a] Correcting container of "0VHX2ovsx6E.m4a"
# [ExtractAudio] Destination: 0VHX2ovsx6E.wav
# Deleting original file 0VHX2ovsx6E.m4a (pass -k to keep)
# [download] Downloading item 404 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=b4_3OIIx_9s
# [youtube] b4_3OIIx_9s: Downloading webpage
# [youtube] b4_3OIIx_9s: Downloading ios player API JSON
# [youtube] b4_3OIIx_9s: Downloading android player API JSON
# [youtube] b4_3OIIx_9s: Downloading m3u8 information
# [info] b4_3OIIx_9s: Downloading 1 format(s): 140
# [download] Destination: b4_3OIIx_9s.m4a
# [download] 100% of    3.49MiB in 00:00:00 at 32.78MiB/s
# [FixupM4a] Correcting container of "b4_3OIIx_9s.m4a"
# [ExtractAudio] Destination: b4_3OIIx_9s.wav
# Deleting original file b4_3OIIx_9s.m4a (pass -k to keep)
# [download] Downloading item 405 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CZtFAo17iLg
# [youtube] CZtFAo17iLg: Downloading webpage
# [youtube] CZtFAo17iLg: Downloading ios player API JSON
# [youtube] CZtFAo17iLg: Downloading android player API JSON
# [youtube] CZtFAo17iLg: Downloading m3u8 information
# [info] CZtFAo17iLg: Downloading 1 format(s): 140
# [download] Destination: CZtFAo17iLg.m4a
# [download] 100% of    3.98MiB in 00:00:00 at 25.38MiB/s
# [FixupM4a] Correcting container of "CZtFAo17iLg.m4a"
# [ExtractAudio] Destination: CZtFAo17iLg.wav
# Deleting original file CZtFAo17iLg.m4a (pass -k to keep)
# [download] Downloading item 406 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I6EIA-dhMxQ
# [youtube] I6EIA-dhMxQ: Downloading webpage
# [youtube] I6EIA-dhMxQ: Downloading ios player API JSON
# [youtube] I6EIA-dhMxQ: Downloading android player API JSON
# [youtube] I6EIA-dhMxQ: Downloading m3u8 information
# [info] I6EIA-dhMxQ: Downloading 1 format(s): 140
# [download] Destination: I6EIA-dhMxQ.m4a
# [download] 100% of    4.64MiB in 00:00:00 at 17.99MiB/s
# [FixupM4a] Correcting container of "I6EIA-dhMxQ.m4a"
# [ExtractAudio] Destination: I6EIA-dhMxQ.wav
# Deleting original file I6EIA-dhMxQ.m4a (pass -k to keep)
# [download] Downloading item 407 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NCxGlmCH_ag
# [youtube] NCxGlmCH_ag: Downloading webpage
# [youtube] NCxGlmCH_ag: Downloading ios player API JSON
# [youtube] NCxGlmCH_ag: Downloading android player API JSON
# [youtube] NCxGlmCH_ag: Downloading m3u8 information
# [info] NCxGlmCH_ag: Downloading 1 format(s): 140
# [download] Destination: NCxGlmCH_ag.m4a
# [download] 100% of    4.56MiB in 00:00:00 at 20.47MiB/s
# [FixupM4a] Correcting container of "NCxGlmCH_ag.m4a"
# [ExtractAudio] Destination: NCxGlmCH_ag.wav
# Deleting original file NCxGlmCH_ag.m4a (pass -k to keep)
# [download] Downloading item 408 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=G-4PbMdUr-k
# [youtube] G-4PbMdUr-k: Downloading webpage
# [youtube] G-4PbMdUr-k: Downloading ios player API JSON
# [youtube] G-4PbMdUr-k: Downloading android player API JSON
# [youtube] G-4PbMdUr-k: Downloading m3u8 information
# [info] G-4PbMdUr-k: Downloading 1 format(s): 140
# [download] Destination: G-4PbMdUr-k.m4a
# [download] 100% of    4.04MiB in 00:00:00 at 4.40MiB/s
# [FixupM4a] Correcting container of "G-4PbMdUr-k.m4a"
# [ExtractAudio] Destination: G-4PbMdUr-k.wav
# Deleting original file G-4PbMdUr-k.m4a (pass -k to keep)
# [download] Downloading item 409 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pOiBoLBxVOo
# [youtube] pOiBoLBxVOo: Downloading webpage
# [youtube] pOiBoLBxVOo: Downloading ios player API JSON
# [youtube] pOiBoLBxVOo: Downloading android player API JSON
# [youtube] pOiBoLBxVOo: Downloading m3u8 information
# [info] pOiBoLBxVOo: Downloading 1 format(s): 140
# [download] Destination: pOiBoLBxVOo.m4a
# [download] 100% of    4.58MiB in 00:00:00 at 32.24MiB/s
# [FixupM4a] Correcting container of "pOiBoLBxVOo.m4a"
# [ExtractAudio] Destination: pOiBoLBxVOo.wav
# Deleting original file pOiBoLBxVOo.m4a (pass -k to keep)
# [download] Downloading item 410 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-L-TrdO2auE
# [youtube] -L-TrdO2auE: Downloading webpage
# [youtube] -L-TrdO2auE: Downloading ios player API JSON
# [youtube] -L-TrdO2auE: Downloading android player API JSON
# [youtube] -L-TrdO2auE: Downloading m3u8 information
# [info] -L-TrdO2auE: Downloading 1 format(s): 140
# [download] Destination: -L-TrdO2auE.m4a
# [download] 100% of    5.16MiB in 00:00:00 at 30.63MiB/s
# [FixupM4a] Correcting container of "-L-TrdO2auE.m4a"
# [ExtractAudio] Destination: -L-TrdO2auE.wav
# Deleting original file -L-TrdO2auE.m4a (pass -k to keep)
# [download] Downloading item 411 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e3LbR7OqSdw
# [youtube] e3LbR7OqSdw: Downloading webpage
# [youtube] e3LbR7OqSdw: Downloading ios player API JSON
# [youtube] e3LbR7OqSdw: Downloading android player API JSON
# [youtube] e3LbR7OqSdw: Downloading m3u8 information
# [info] e3LbR7OqSdw: Downloading 1 format(s): 140
# [download] Destination: e3LbR7OqSdw.m4a
# [download] 100% of    4.19MiB in 00:00:00 at 30.98MiB/s
# [FixupM4a] Correcting container of "e3LbR7OqSdw.m4a"
# [ExtractAudio] Destination: e3LbR7OqSdw.wav
# Deleting original file e3LbR7OqSdw.m4a (pass -k to keep)
# [download] Downloading item 412 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xSQIiV2MHtw
# [youtube] xSQIiV2MHtw: Downloading webpage
# [youtube] xSQIiV2MHtw: Downloading ios player API JSON
# [youtube] xSQIiV2MHtw: Downloading android player API JSON
# [youtube] xSQIiV2MHtw: Downloading m3u8 information
# [info] xSQIiV2MHtw: Downloading 1 format(s): 140
# [download] Destination: xSQIiV2MHtw.m4a
# [download] 100% of    3.64MiB in 00:00:00 at 42.77MiB/s
# [FixupM4a] Correcting container of "xSQIiV2MHtw.m4a"
# [ExtractAudio] Destination: xSQIiV2MHtw.wav
# Deleting original file xSQIiV2MHtw.m4a (pass -k to keep)
# [download] Downloading item 413 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=
of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PdUiCJnRptk
# [youtube] PdUiCJnRptk: Downloading webpage
# [youtube] PdUiCJnRptk: Downloading ios player API JSON
# [youtube] PdUiCJnRptk: Downloading android player API JSON
# [youtube] PdUiCJnRptk: Downloading m3u8 information
# [info] PdUiCJnRptk: Downloading 1 format(s): 140
# [download] Destination: PdUiCJnRptk.m4a
# [download] 100% of    3.52MiB in 00:00:00 at 44.71MiB/s
# [FixupM4a] Correcting container of "PdUiCJnRptk.m4a"
# [ExtractAudio] Destination: PdUiCJnRptk.wav
# Deleting original file PdUiCJnRptk.m4a (pass -k to keep)
# [download] Downloading item 419 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IEpu-rP6ji8
# [youtube] IEpu-rP6ji8: Downloading webpage
# [youtube] IEpu-rP6ji8: Downloading ios player API JSON
# [youtube] IEpu-rP6ji8: Downloading android player API JSON
# [youtube] IEpu-rP6ji8: Downloading m3u8 information
# [info] IEpu-rP6ji8: Downloading 1 format(s): 140
# [download] Destination: IEpu-rP6ji8.m4a
# [download] 100% of    4.51MiB in 00:00:01 at 4.25MiB/s
# [FixupM4a] Correcting container of "IEpu-rP6ji8.m4a"
# [ExtractAudio] Destination: IEpu-rP6ji8.wav
# Deleting original file IEpu-rP6ji8.m4a (pass -k to keep)
# [download] Downloading item 420 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rMooWhz0CNA
# [youtube] rMooWhz0CNA: Downloading webpage
# [youtube] rMooWhz0CNA: Downloading ios player API JSON
# [youtube] rMooWhz0CNA: Downloading android player API JSON
# [youtube] rMooWhz0CNA: Downloading m3u8 information
# [info] rMooWhz0CNA: Downloading 1 format(s): 140
# [download] Destination: rMooWhz0CNA.m4a
# [download] 100% of    3.88MiB in 00:00:00 at 24.99MiB/s
# [FixupM4a] Correcting container of "rMooWhz0CNA.m4a"
# [ExtractAudio] Destination: rMooWhz0CNA.wav
# Deleting original file rMooWhz0CNA.m4a (pass -k to keep)
# [download] Downloading item 421 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8wW-0x8_V-E
# [youtube] 8wW-0x8_V-E: Downloading webpage
# [youtube] 8wW-0x8_V-E: Downloading ios player API JSON
# [youtube] 8wW-0x8_V-E: Downloading android player API JSON
# [youtube] 8wW-0x8_V-E: Downloading m3u8 information
# [info] 8wW-0x8_V-E: Downloading 1 format(s): 140
# [download] Destination: 8wW-0x8_V-E.m4a
# [download] 100% of    3.99MiB in 00:00:00 at 24.16MiB/s
# [FixupM4a] Correcting container of "8wW-0x8_V-E.m4a"
# [ExtractAudio] Destination: 8wW-0x8_V-E.wav
# Deleting original file 8wW-0x8_V-E.m4a (pass -k to keep)
# [download] Downloading item 422 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HU_IXLl1m8A
# [youtube] HU_IXLl1m8A: Downloading webpage
# [youtube] HU_IXLl1m8A: Downloading ios player API JSON
# [youtube] HU_IXLl1m8A: Downloading android player API JSON
# [youtube] HU_IXLl1m8A: Downloading m3u8 information
# [info] HU_IXLl1m8A: Downloading 1 format(s): 140
# [download] Destination: HU_IXLl1m8A.m4a
# [download] 100% of    4.18MiB in 00:00:00 at 9.33MiB/s
# [FixupM4a] Correcting container of "HU_IXLl1m8A.m4a"
# [ExtractAudio] Destination: HU_IXLl1m8A.wav
# Deleting original file HU_IXLl1m8A.m4a (pass -k to keep)
# [download] Downloading item 423 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UNJ0mtOFG-4
# [youtube] UNJ0mtOFG-4: Downloading webpage
# [youtube] UNJ0mtOFG-4: Downloading ios player API JSON
# [youtube] UNJ0mtOFG-4: Downloading android player API JSON
# [youtube] UNJ0mtOFG-4: Downloading m3u8 information
# [info] UNJ0mtOFG-4: Downloading 1 format(s): 140
# [download] Destination: UNJ0mtOFG-4.m4a
# [download] 100% of    5.12MiB in 00:00:00 at 47.47MiB/s
# [FixupM4a] Correcting container of "UNJ0mtOFG-4.m4a"
# [ExtractAudio] Destination: UNJ0mtOFG-4.wav
# Deleting original file UNJ0mtOFG-4.m4a (pass -k to keep)
# [download] Downloading item 424 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YbYBTtcJ3hw
# [youtube] YbYBTtcJ3hw: Downloading webpage
# [youtube] YbYBTtcJ3hw: Downloading ios player API JSON
# [youtube] YbYBTtcJ3hw: Downloading android player API JSON
# [youtube] YbYBTtcJ3hw: Downloading m3u8 information
# [info] YbYBTtcJ3hw: Downloading 1 format(s): 140
# [download] Destination: YbYBTtcJ3hw.m4a
# [download] 100% of    3.73MiB in 00:00:00 at 22.29MiB/s
# [FixupM4a] Correcting container of "YbYBTtcJ3hw.m4a"
# [ExtractAudio] Destination: YbYBTtcJ3hw.wav
# Deleting original file YbYBTtcJ3hw.m4a (pass -k to keep)
# [download] Downloading item 425 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ASeoOFYDrSk
# [youtube] ASeoOFYDrSk: Downloading webpage
# [youtube] ASeoOFYDrSk: Downloading ios player API JSON
# [youtube] ASeoOFYDrSk: Downloading android player API JSON
# [youtube] ASeoOFYDrSk: Downloading m3u8 information
# [info] ASeoOFYDrSk: Downloading 1 format(s): 140
# [download] Destination: ASeoOFYDrSk.m4a
# [download] 100% of    3.45MiB in 00:00:00 at 22.21MiB/s
# [FixupM4a] Correcting container of "ASeoOFYDrSk.m4a"
# [ExtractAudio] Destination: ASeoOFYDrSk.wav
# Deleting original file ASeoOFYDrSk.m4a (pass -k to keep)
# [download] Downloading item 426 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qsgAdo5d258
# [youtube] qsgAdo5d258: Downloading webpage
# [youtube] qsgAdo5d258: Downloading ios player API JSON
# [youtube] qsgAdo5d258: Downloading android player API JSON
# [youtube] qsgAdo5d258: Downloading m3u8 information
# [info] qsgAdo5d258: Downloading 1 format(s): 140
# [download] Destination: qsgAdo5d258.m4a
# [download] 100% of    3.77MiB in 00:00:00 at 6.73MiB/s
# [FixupM4a] Correcting container of "qsgAdo5d258.m4a"
# [ExtractAudio] Destination: qsgAdo5d258.wav
# Deleting original file qsgAdo5d258.m4a (pass -k to keep)
# [download] Downloading item 427 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rhOFrk-KHIM
# [youtube] rhOFrk-KHIM: Downloading webpage
# [youtube] rhOFrk-KHIM: Downloading ios player API JSON
# [youtube] rhOFrk-KHIM: Downloading android player API JSON
# [youtube] rhOFrk-KHIM: Downloading m3u8 information
# [info] rhOFrk-KHIM: Downloading 1 format(s): 140
# [download] Destination: rhOFrk-KHIM.m4a
# [download] 100% of    4.29MiB in 00:00:00 at 24.99MiB/s
# [FixupM4a] Correcting container of "rhOFrk-KHIM.m4a"
# [ExtractAudio] Destination: rhOFrk-KHIM.wav
# Deleting original file rhOFrk-KHIM.m4a (pass -k to keep)
# [download] Downloading item 428 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=__9zgdiGf5o
# [youtube] __9zgdiGf5o: Downloading webpage
# [youtube] __9zgdiGf5o: Downloading ios player API JSON
# [youtube] __9zgdiGf5o: Downloading android player API JSON
# [youtube] __9zgdiGf5o: Downloading m3u8 information
# [info] __9zgdiGf5o: Downloading 1 format(s): 140
# [download] Destination: __9zgdiGf5o.m4a
# [download] 100% of    4.06MiB in 00:00:00 at 21.04MiB/s
# [FixupM4a] Correcting container of "__9zgdiGf5o.m4a"
# [ExtractAudio] Destination: __9zgdiGf5o.wav
# Deleting original file __9zgdiGf5o.m4a (pass -k to keep)
# [download] Downloading item 429 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ySEZdppcVvg
# [youtube] ySEZdppcVvg: Downloading webpage
# [youtube] ySEZdppcVvg: Downloading ios player API JSON
# [youtube] ySEZdppcVvg: Downloading android player API JSON
# [youtube] ySEZdppcVvg: Downloading m3u8 information
# [info] ySEZdppcVvg: Downloading 1 format(s): 140
# [download] Destination: ySEZdppcVvg.m4a
# [download] 100% of    4.62MiB in 00:00:00 at 31.94MiB/s
# [FixupM4a] Correcting container of "ySEZdppcVvg.m4a"
# [ExtractAudio] Destination: ySEZdppcVvg.wav
# Deleting original file ySEZdppcVvg.m4a (pass -k to keep)
# [download] Downloading item 430 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IFP72emyx_c
# [youtube] IFP72emyx_c: Downloading webpage
# [youtube] IFP72emyx_c: Downloading ios player API JSON
# [youtube] IFP72emyx_c: Downloading android player API JSON
# [youtube] IFP72emyx_c: Downloading m3u8 information
# [info] IFP72emyx_c: Downloading 1 format(s): 140
# [download] Destination: IFP72emyx_c.m4a
# [download] 100% of    3.21MiB in 00:00:00 at 38.91MiB/s
# [FixupM4a] Correcting container of "IFP72emyx_c.m4a"
# [ExtractAudio] Destination: IFP72emyx_c.wav
# Deleting original file IFP72emyx_c.m4a (pass -k to keep)
# [download] Downloading item 431 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XnXXLFYSD58
# [youtube] XnXXLFYSD58: Downloading webpage
# [youtube] XnXXLFYSD58: Downloading ios player API JSON
# [youtube] XnXXLFYSD58: Downloading android player API JSON
# [youtube] XnXXLFYSD58: Downloading m3u8 information
# [info] XnXXLFYSD58: Downloading 1 format(s): 140
# [download] Destination: XnXXLFYSD58.m4a
# [download] 100% of    3.83MiB in 00:00:00 at 26.51MiB/s
# [FixupM4a] Correcting container of "XnXXLFYSD58.m4a"
# [ExtractAudio] Destination: XnXXLFYSD58.wav
# Deleting original file XnXXLFYSD58.m4a (pass -k to keep)
# [download] Downloading item 432 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=i_aBmXS1Jvo
# [youtube] i_aBmXS1Jvo: Downloading webpage
# [youtube] i_aBmXS1Jvo: Downloading ios player API JSON
# [youtube] i_aBmXS1Jvo: Downloading android player API JSON
# [youtube] i_aBmXS1Jvo: Downloading m3u8 information
# [info] i_aBmXS1Jvo: Downloading 1 format(s): 140
# [download] Destination: i_aBmXS1Jvo.m4a
# [download] 100% of    4.33MiB in 00:00:00 at 26.01MiB/s
# [FixupM4a] Correcting container of "i_aBmXS1Jvo.m4a"
# [ExtractAudio] Destination: i_aBmXS1Jvo.wav
# Deleting original file i_aBmXS1Jvo.m4a (pass -k to keep)
# [download] Downloading item 433 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=grigZ4E34f4
# [youtube] grigZ4E34f4: Downloading webpage
# [youtube] grigZ4E34f4: Downloading ios player API JSON
# [youtube] grigZ4E34f4: Downloading android player API JSON
# [youtube] grigZ4E34f4: Downloading m3u8 information
# [info] grigZ4E34f4: Downloading 1 format(s): 140
# [download] Destination: grigZ4E34f4.m4a
# [download] 100% of    3.26MiB in 00:00:00 at 25.52MiB/s
# [FixupM4a] Correcting container of "grigZ4E34f4.m4a"
# [ExtractAudio] Destination: grigZ4E34f4.wav
# Deleting original file grigZ4E34f4.m4a (pass -k to keep)
# [download] Downloading item 434 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mMVdPKvokVc
# [youtube] mMVdPKvokVc: Downloading webpage
# [youtube] mMVdPKvokVc: Downloading ios player API JSON
# [youtube] mMVdPKvokVc: Downloading android player API JSON
# [youtube] mMVdPKvokVc: Downloading m3u8 information
# [info] mMVdPKvokVc: Downloading 1 format(s): 140
# [download] Destination: mMVdPKvokVc.m4a
# [download] 100% of    5.38MiB in 00:00:00 at 32.03MiB/s
# [FixupM4a] Correcting container of "mMVdPKvokVc.m4a"
# [ExtractAudio] Destination: mMVdPKvokVc.wav
# Deleting original file mMVdPKvokVc.m4a (pass -k to keep)
# [download] Downloading item 435 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HZras9mV9ns
# [youtube] HZras9mV9ns: Downloading webpage
# [youtube] HZras9mV9ns: Downloading ios player API JSON
# [youtube] HZras9mV9ns: Downloading android player API JSON
# [youtube] HZras9mV9ns: Downloading m3u8 information
# [info] HZras9mV9ns: Downloading 1 format(s): 140
# [download] Destination: HZras9mV9ns.m4a
# [download] 100% of    4.03MiB in 00:00:00 at 27.68MiB/s
# [FixupM4a] Correcting container of "HZras9mV9ns.m4a"
# [ExtractAudio] Destination: HZras9mV9ns.wav
# Deleting original file HZras9mV9ns.m4a (pass -k to keep)
# [download] Downloading item 436 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EwP8sgu6LNA
# [youtube] EwP8sgu6LNA: Downloading webpage
# [youtube] EwP8sgu6LNA: Downloading ios player API JSON
# [youtube] EwP8sgu6LNA: Downloading android player API JSON
# [youtube] EwP8sgu6LNA: Downloading m3u8 information
# [info] EwP8sgu6LNA: Downloading 1 format(s): 140
# [download] Destination: EwP8sgu6LNA.m4a
# [download] 100% of    4.66MiB in 00:00:00 at 33.07MiB/s
# [FixupM4a] Correcting container of "EwP8sgu6LNA.m4a"
# [ExtractAudio] Destination: EwP8sgu6LNA.wav
# Deleting original file EwP8sgu6LNA.m4a (pass -k to keep)
# [download] Downloading item 437 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SAtTXASJK1c
# [youtube] SAtTXASJK1c: Downloading webpage
# [youtube] SAtTXASJK1c: Downloading ios player API JSON
# [youtube] SAtTXASJK1c: Downloading android player API JSON
# [youtube] SAtTXASJK1c: Downloading m3u8 information
# [info] SAtTXASJK1c: Downloading 1 format(s): 140
# [download] Destination: SAtTXASJK1c.m4a
# [download] 100% of    3.95MiB in 00:00:01 at 2.71MiB/s
# [FixupM4a] Correcting container of "SAtTXASJK1c.m4a"
# [ExtractAudio] Destination: SAtTXASJK1c.wav
# Deleting original file SAtTXASJK1c.m4a (pass -k to keep)
# [download] Downloading item 438 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dQlRhxHpkl0
# [youtube] dQlRhxHpkl0: Downloading webpage
# [youtube] dQlRhxHpkl0: Downloading ios player API JSON
# [youtube] dQlRhxHpkl0: Downloading android player API JSON
# [youtube] dQlRhxHpkl0: Downloading m3u8 information
# [info] dQlRhxHpkl0: Downloading 1 format(s): 140
# [download] Destination: dQlRhxHpkl0.m4a
# [download] 100% of    4.28MiB in 00:00:00 at 23.34MiB/s
# [FixupM4a] Correcting container of "dQlRhxHpkl0.m4a"
# [ExtractAudio] Destination: dQlRhxHpkl0.wav
# Deleting original file dQlRhxHpkl0.m4a (pass -k to keep)
# [download] Downloading item 439 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Zh-By3dy_bc
# [youtube] Zh-By3dy_bc: Downloading webpage
# [youtube] Zh-By3dy_bc: Downloading ios player API JSON
# [youtube] Zh-By3dy_bc: Downloading android player API JSON
# [youtube] Zh-By3dy_bc: Downloading m3u8 information
# [info] Zh-By3dy_bc: Downloading 1 format(s): 140
# [download] Destination: Zh-By3dy_bc.m4a
# [download] 100% of    3.92MiB in 00:00:01 at 3.13MiB/s
# [FixupM4a] Correcting container of "Zh-By3dy_bc.m4a"
# [ExtractAudio] Destination: Zh-By3dy_bc.wav
# Deleting original file Zh-By3dy_bc.m4a (pass -k to keep)
# [download] Downloading item 440 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lMV7D1pjba0
# [youtube] lMV7D1pjba0: Downloading webpage
# [youtube] lMV7D1pjba0: Downloading ios player API JSON
# [youtube] lMV7D1pjba0: Downloading android player API JSON
# [youtube] lMV7D1pjba0: Downloading m3u8 information
# [info] lMV7D1pjba0: Downloading 1 format(s): 140
# [download] Destination: lMV7D1pjba0.m4a
# [download] 100% of    4.01MiB in 00:00:01 at 2.19MiB/s
# [FixupM4a] Correcting container of "lMV7D1pjba0.m4a"
# [ExtractAudio] Destination: lMV7D1pjba0.wav
# Deleting original file lMV7D1pjba0.m4a (pass -k to keep)
# [download] Downloading item 441 of 1344
# ...
# [download] Downloading item 754 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=F8lCfxJ1MTQ
# [youtube] F8lCfxJ1MTQ: Downloading webpage
# [youtube] F8lCfxJ1MTQ: Downloading ios player API JSON
# [youtube] F8lCfxJ1MTQ: Downloading android player API JSON
# [youtube] F8lCfxJ1MTQ: Downloading m3u8 information
# [info] F8lCfxJ1MTQ: Downloading 1 format(s): 140
# [download] Destination: F8lCfxJ1MTQ.m4a
# [download] 100% of    4.15MiB in 00:00:00 at 20.15MiB/s
# [FixupM4a] Correcting container of "F8lCfxJ1MTQ.m4a"
# [ExtractAudio] Destination: F8lCfxJ1MTQ.wav
# Deleting original file F8lCfxJ1MTQ.m4a (pass -k to keep)
# [download] Downloading item 755 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mwZSQBixpFE
# [youtube] mwZSQBixpFE: Downloading webpage
# [youtube] mwZSQBixpFE: Downloading ios player API JSON
# [youtube] mwZSQBixpFE: Downloading android player API JSON
# [youtube] mwZSQBixpFE: Downloading m3u8 information
# [info] mwZSQBixpFE: Downloading 1 format(s): 140
# [download] Destination: mwZSQBixpFE.m4a
# [download] 100% of    5.07MiB in 00:00:00 at 26.61MiB/s
# [FixupM4a] Correcting container of "mwZSQBixpFE.m4a"
# [ExtractAudio] Destination: mwZSQBixpFE.wav
# Deleting original file mwZSQBixpFE.m4a (pass -k to keep)
# [download] Downloading item 756 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AM9W--YXERk
# [youtube] AM9W--YXERk: Downloading webpage
# [youtube] AM9W--YXERk: Downloading ios player API JSON
# [youtube] AM9W--YXERk: Downloading android player API JSON
# [youtube] AM9W--YXERk: Downloading m3u8 information
# [info] AM9W--YXERk: Downloading 1 format(s): 140
# [download] Destination: AM9W--YXERk.m4a
# [download] 100% of    4.02MiB in 00:00:00 at 21.41MiB/s
# [FixupM4a] Correcting container of "AM9W--YXERk.m4a"
# [ExtractAudio] Destination: AM9W--YXERk.wav
# Deleting original file AM9W--YXERk.m4a (pass -k to keep)
# [download] Downloading item 757 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0F18CyCwT3w
# [youtube] 0F18CyCwT3w: Downloading webpage
# [youtube] 0F18CyCwT3w: Downloading ios player API JSON
# [youtube] 0F18CyCwT3w: Downloading android player API JSON
# [youtube] 0F18CyCwT3w: Downloading m3u8 information
# [info] 0F18CyCwT3w: Downloading 1 format(s): 140
# [download] Destination: 0F18CyCwT3w.m4a
# [download] 100% of    3.16MiB in 00:00:00 at 35.37MiB/s
# [FixupM4a] Correcting container of "0F18CyCwT3w.m4a"
# [ExtractAudio] Destination: 0F18CyCwT3w.wav
# Deleting original file 0F18CyCwT3w.m4a (pass -k to keep)
# [download] Downloading item 758 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vh-lDIc-biU
# [youtube] vh-lDIc-biU: Downloading webpage
# [youtube] vh-lDIc-biU: Downloading ios player API JSON
# [youtube] vh-lDIc-biU: Downloading android player API JSON
# [youtube] vh-lDIc-biU: Downloading m3u8 information
# [info] vh-lDIc-biU: Downloading 1 format(s): 140
# [download] Destination: vh-lDIc-biU.m4a
# [download] 100% of    5.91MiB in 00:00:00 at 33.83MiB/s
# [FixupM4a] Correcting container of "vh-lDIc-biU.m4a"
# [ExtractAudio] Destination: vh-lDIc-biU.wav
# Deleting original file vh-lDIc-biU.m4a (pass -k to keep)
# [download] Downloading item 759 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dSLQwzx1CWg
# [youtube] dSLQwzx1CWg: Downloading webpage
# [youtube] dSLQwzx1CWg: Downloading ios player API JSON
# [youtube] dSLQwzx1CWg: Downloading android player API JSON
# [youtube] dSLQwzx1CWg: Downloading m3u8 information
# [info] dSLQwzx1CWg: Downloading 1 format(s): 140
# [download] Destination: dSLQwzx1CWg.m4a
# [download] 100% of    3.75MiB in 00:00:00 at 33.12MiB/s
# [FixupM4a] Correcting container of "dSLQwzx1CWg.m4a"
# [ExtractAudio] Destination: dSLQwzx1CWg.wav
# Deleting original file dSLQwzx1CWg.m4a (pass -k to keep)
# [download] Downloading item 760 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v
of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SEjiyJ04uig
# [youtube] SEjiyJ04uig: Downloading webpage
# [youtube] SEjiyJ04uig: Downloading ios player API JSON
# [youtube] SEjiyJ04uig: Downloading android player API JSON
# [youtube] SEjiyJ04uig: Downloading m3u8 information
# [info] SEjiyJ04uig: Downloading 1 format(s): 140
# [download] Destination: SEjiyJ04uig.m4a
# [download] 100% of    4.50MiB in 00:00:00 at 28.11MiB/s
# [FixupM4a] Correcting container of "SEjiyJ04uig.m4a"
# [ExtractAudio] Destination: SEjiyJ04uig.wav
# Deleting original file SEjiyJ04uig.m4a (pass -k to keep)
# [download] Downloading item 766 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I3FHA_qASro
# [youtube] I3FHA_qASro: Downloading webpage
# [youtube] I3FHA_qASro: Downloading ios player API JSON
# [youtube] I3FHA_qASro: Downloading android player API JSON
# [youtube] I3FHA_qASro: Downloading m3u8 information
# [info] I3FHA_qASro: Downloading 1 format(s): 140
# [download] Destination: I3FHA_qASro.m4a
# [download] 100% of    4.69MiB in 00:00:00 at 36.62MiB/s
# [FixupM4a] Correcting container of "I3FHA_qASro.m4a"
# [ExtractAudio] Destination: I3FHA_qASro.wav
# Deleting original file I3FHA_qASro.m4a (pass -k to keep)
# [download] Downloading item 767 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NJX50y15rvw
# [youtube] NJX50y15rvw: Downloading webpage
# [youtube] NJX50y15rvw: Downloading ios player API JSON
# [youtube] NJX50y15rvw: Downloading android player API JSON
# [youtube] NJX50y15rvw: Downloading m3u8 information
# [info] NJX50y15rvw: Downloading 1 format(s): 140
# [download] Destination: NJX50y15rvw.m4a
# [download] 100% of    4.44MiB in 00:00:00 at 36.23MiB/s
# [FixupM4a] Correcting container of "NJX50y15rvw.m4a"
# [ExtractAudio] Destination: NJX50y15rvw.wav
# Deleting original file NJX50y15rvw.m4a (pass -k to keep)
# [download] Downloading item 768 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0VHX2ovsx6E
# [youtube] 0VHX2ovsx6E: Downloading webpage
# [youtube] 0VHX2ovsx6E: Downloading ios player API JSON
# [youtube] 0VHX2ovsx6E: Downloading android player API JSON
# [youtube] 0VHX2ovsx6E: Downloading m3u8 information
# [info] 0VHX2ovsx6E: Downloading 1 format(s): 140
# [download] Destination: 0VHX2ovsx6E.m4a
# [download] 100% of    3.27MiB in 00:00:00 at 36.91MiB/s
# [FixupM4a] Correcting container of "0VHX2ovsx6E.m4a"
# [ExtractAudio] Destination: 0VHX2ovsx6E.wav
# Deleting original file 0VHX2ovsx6E.m4a (pass -k to keep)
# [download] Downloading item 769 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=b4_3OIIx_9s
# [youtube] b4_3OIIx_9s: Downloading webpage
# [youtube] b4_3OIIx_9s: Downloading ios player API JSON
# [youtube] b4_3OIIx_9s: Downloading android player API JSON
# [youtube] b4_3OIIx_9s: Downloading m3u8 information
# [info] b4_3OIIx_9s: Downloading 1 format(s): 140
# [download] Destination: b4_3OIIx_9s.m4a
# [download] 100% of    3.49MiB in 00:00:00 at 31.00MiB/s
# [FixupM4a] Correcting container of "b4_3OIIx_9s.m4a"
# [ExtractAudio] Destination: b4_3OIIx_9s.wav
# Deleting original file b4_3OIIx_9s.m4a (pass -k to keep)
# [download] Downloading item 770 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CZtFAo17iLg
# [youtube] CZtFAo17iLg: Downloading webpage
# [youtube] CZtFAo17iLg: Downloading ios player API JSON
# [youtube] CZtFAo17iLg: Downloading android player API JSON
# [youtube] CZtFAo17iLg: Downloading m3u8 information
# [info] CZtFAo17iLg: Downloading 1 format(s): 140
# [download] Destination: CZtFAo17iLg.m4a
# [download] 100% of    3.98MiB in 00:00:00 at 21.05MiB/s
# [FixupM4a] Correcting container of "CZtFAo17iLg.m4a"
# [ExtractAudio] Destination: CZtFAo17iLg.wav
# Deleting original file CZtFAo17iLg.m4a (pass -k to keep)
# [download] Downloading item 771 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I6EIA-dhMxQ
# [youtube] I6EIA-dhMxQ: Downloading webpage
# [youtube] I6EIA-dhMxQ: Downloading ios player API JSON
# [youtube] I6EIA-dhMxQ: Downloading android player API JSON
# [youtube] I6EIA-dhMxQ: Downloading m3u8 information
# [info] I6EIA-dhMxQ: Downloading 1 format(s): 140
# [download] Destination: I6EIA-dhMxQ.m4a
# [download] 100% of    4.64MiB in 00:00:00 at 25.19MiB/s
# [FixupM4a] Correcting container of "I6EIA-dhMxQ.m4a"
# [ExtractAudio] Destination: I6EIA-dhMxQ.wav
# Deleting original file I6EIA-dhMxQ.m4a (pass -k to keep)
# [download] Downloading item 772 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NCxGlmCH_ag
# [youtube] NCxGlmCH_ag: Downloading webpage
# [youtube] NCxGlmCH_ag: Downloading ios player API JSON
# [youtube] NCxGlmCH_ag: Downloading android player API JSON
# [youtube] NCxGlmCH_ag: Downloading m3u8 information
# [info] NCxGlmCH_ag: Downloading 1 format(s): 140
# [download] Destination: NCxGlmCH_ag.m4a
# [download] 100% of    4.56MiB in 00:00:00 at 27.38MiB/s
# [FixupM4a] Correcting container of "NCxGlmCH_ag.m4a"
# [ExtractAudio] Destination: NCxGlmCH_ag.wav
# Deleting original file NCxGlmCH_ag.m4a (pass -k to keep)
# [download] Downloading item 773 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=G-4PbMdUr-k
# [youtube] G-4PbMdUr-k: Downloading webpage
# [youtube] G-4PbMdUr-k: Downloading ios player API JSON
# [youtube] G-4PbMdUr-k: Downloading android player API JSON
# [youtube] G-4PbMdUr-k: Downloading m3u8 information
# [info] G-4PbMdUr-k: Downloading 1 format(s): 140
# [download] Destination: G-4PbMdUr-k.m4a
# [download] 100% of    4.04MiB in 00:00:00 at 12.67MiB/s
# [FixupM4a] Correcting container of "G-4PbMdUr-k.m4a"
# [ExtractAudio] Destination: G-4PbMdUr-k.wav
# Deleting original file G-4PbMdUr-k.m4a (pass -k to keep)
# [download] Downloading item 774 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=pOiBoLBxVOo
# [youtube] pOiBoLBxVOo: Downloading webpage
# [youtube] pOiBoLBxVOo: Downloading ios player API JSON
# [youtube] pOiBoLBxVOo: Downloading android player API JSON
# [youtube] pOiBoLBxVOo: Downloading m3u8 information
# [info] pOiBoLBxVOo: Downloading 1 format(s): 140
# [download] Destination: pOiBoLBxVOo.m4a
# [download] 100% of    4.58MiB in 00:00:00 at 34.36MiB/s
# [FixupM4a] Correcting container of "pOiBoLBxVOo.m4a"
# [ExtractAudio] Destination: pOiBoLBxVOo.wav
# Deleting original file pOiBoLBxVOo.m4a (pass -k to keep)
# [download] Downloading item 775 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-L-TrdO2auE
# [youtube] -L-TrdO2auE: Downloading webpage
# [youtube] -L-TrdO2auE: Downloading ios player API JSON
# [youtube] -L-TrdO2auE: Downloading android player API JSON
# [youtube] -L-TrdO2auE: Downloading m3u8 information
# [info] -L-TrdO2auE: Downloading 1 format(s): 140
# [download] Destination: -L-TrdO2auE.m4a
# [download] 100% of    5.16MiB in 00:00:00 at 25.02MiB/s
# [FixupM4a] Correcting container of "-L-TrdO2auE.m4a"
# [ExtractAudio] Destination: -L-TrdO2auE.wav
# Deleting original file -L-TrdO2auE.m4a (pass -k to keep)
# [download] Downloading item 776 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e3LbR7OqSdw
# [youtube] e3LbR7OqSdw: Downloading webpage
# [youtube] e3LbR7OqSdw: Downloading ios player API JSON
# [youtube] e3LbR7OqSdw: Downloading android player API JSON
# [youtube] e3LbR7OqSdw: Downloading m3u8 information
# [info] e3LbR7OqSdw: Downloading 1 format(s): 140
# [download] Destination: e3LbR7OqSdw.m4a
# [download] 100% of    4.19MiB in 00:00:00 at 27.30MiB/s
# [FixupM4a] Correcting container of "e3LbR7OqSdw.m4a"
# [ExtractAudio] Destination: e3LbR7OqSdw.wav
# Deleting original file e3LbR7OqSdw.m4a (pass -k to keep)
# [download] Downloading item 777 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xSQIiV2MHtw
# [youtube] xSQIiV2MHtw: Downloading webpage
# [youtube] xSQIiV2MHtw: Downloading ios player API JSON
# [youtube] xSQIiV2MHtw: Downloading android player API JSON
# [youtube] xSQIiV2MHtw: Downloading m3u8 information
# [info] xSQIiV2MHtw: Downloading 1 format(s): 140
# [download] Destination: xSQIiV2MHtw.m4a
# [download] 100% of    3.64MiB in 00:00:00 at 29.07MiB/s
# [FixupM4a] Correcting container of "xSQIiV2MHtw.m4a"
# [ExtractAudio] Destination: xSQIiV2MHtw.wav
# Deleting original file xSQIiV2MHtw.m4a (pass -k to keep)
# [download] Downloading item 778 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yQ4s0twG3wU
# [youtube] yQ4s0twG3wU: Downloading webpage
# [youtube] yQ4s0twG3wU: Downloading ios player API JSON
# [youtube] yQ4s0twG3wU: Downloading android player API JSON
# [youtube] yQ4s0twG3wU: Downloading m3u8 information
# [info] yQ4s0twG3wU: Downloading 1 format(s): 140
# [download] Destination: yQ4s0twG3wU.m4a
# [download] 100% of    3.64MiB in 00:00:00 at 26.54MiB/s
# [FixupM4a] Correcting container of "yQ4s0twG3wU.m4a"
# [ExtractAudio] Destination: yQ4s0twG3wU.wav
# Deleting original file yQ4s0twG3wU.m4a (pass -k to keep)
# [download] Downloading item 779 of 1344
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TQD46xsS5Oo
# [youtube] TQD46xsS5Oo: Downloading webpage
# [youtube] TQD46xsS5Oo: Downloading ios player API JSON
# [youtube] TQD46xsS5Oo: Downloading android player API JSON
# [youtube] TQD46xsS5Oo: Downloading m3u8 information
# [info] TQD46xsS5Oo: Downloading 1 format(s): 140
# [download] Destination: TQD46xsS5Oo.m4a
# [download] 100% of    3.61MiB in 00:00:00 at 29.03MiB/s

# %%
def seconds_to_time_format(s):
    # Convert seconds to hours, minutes, seconds, and milliseconds
    hours = s // 3600
    s %= 3600
    minutes = s // 60
    s %= 60
    seconds = s // 1
    milliseconds = round((s % 1) * 1000)

    # Return the formatted string
    return f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d},{int(milliseconds):03d}"

#@markdown # **Run the model** 🚀

#@markdown Run this cell to execute the transcription of the video. This can take a while and very based on the length of the video and the number of parameters of the model selected above.

#@markdown ## **Parameters** ⚙️

#@markdown ### **Behavior control**
#@markdown #### Language
language = "ja" #@param ["auto", "en", "zh", "ja", "fr", "de"] {allow-input: true}
#@markdown #### initial prompt
initial_prompt = "" #@param {type:"string"}
#@markdown ---
#@markdown #### Word-level timestamps
word_level_timestamps = False #@param {type:"boolean"}
#@markdown ---
#@markdown #### VAD filter
vad_filter = False #@param {type:"boolean"}
vad_filter_min_silence_duration_ms = 50 #@param {type:"integer"}
#@markdown ---
#@markdown #### Output(Default is srt, txt if `text_only` be checked )
text_only = True #@param {type:"boolean"}


segments, info = model.transcribe(str(video_path_local), beam_size=5,
                                  language=None if language == "auto" else language,
                                  initial_prompt=initial_prompt,
                                  word_timestamps=word_level_timestamps,
                                  vad_filter=vad_filter,
                                  vad_parameters=dict(min_silence_duration_ms=vad_filter_min_silence_duration_ms))

display(Markdown(f"Detected language '{info.language}' with probability {info.language_probability}"))

ext_name = '.txt' if text_only else ".srt"
transcript_file_name = video_path_local.stem + ext_name
sentence_idx = 1
with open(transcript_file_name, 'w') as f:
  for segment in segments:
    if word_level_timestamps:
      for word in segment.words:
        ts_start = seconds_to_time_format(word.start)
        ts_end = seconds_to_time_format(word.end)
        print(f"[{ts_start} --> {ts_end}] {word.word}")
        if not text_only:
          f.write(f"{sentence_idx}\n")
          f.write(f"{ts_start} --> {ts_end}\n")
          f.write(f"{word.word}\n\n")
        else:
          f.write(f"{word.word}")
        f.write("\n")
        sentence_idx = sentence_idx + 1
    else:
      ts_start = seconds_to_time_format(segment.start)
      ts_end = seconds_to_time_format(segment.end)
      print(f"[{ts_start} --> {ts_end}] {segment.text}")
      if not text_only:
        f.write(f"{sentence_idx}\n")
        f.write(f"{ts_start} --> {ts_end}\n")
        f.write(f"{segment.text.strip()}\n\n")
      else:
        f.write(f"{segment.text.strip()}\n")
      sentence_idx = sentence_idx + 1

try:
  shutil.copy(video_path_local.parent / transcript_file_name,
            drive_whisper_path / transcript_file_name
  )
  display(Markdown(f"**Transcript file created: {drive_whisper_path / transcript_file_name}**"))
except:
  display(Markdown(f"**Transcript file created: {video_path_local.parent / transcript_file_name}**"))
